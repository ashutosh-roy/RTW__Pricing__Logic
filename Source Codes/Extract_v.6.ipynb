# %%
import xlrd
import json
import csv
# from google.colab import files
# uploaded = files.upload()

# %%
book = xlrd.open_workbook("../RTW.xls")

# %%
print("The number of worksheets is {0}".format(book.nsheets))
print("Worksheet name(s): {0}".format(book.sheet_names()))
# Out:
# The number of worksheets is 19
# Worksheet name(s): ['JOHOR', 'MELAKA', 'N9', 'ZON SELATAN', 'PERLIS', 'KEDAH', 'PP', 'PERAK', 'ZON UTARA', 'PAHANG', 'KELANTAN', 'TERENGGANU', 'ZON TIMUR', 'SABAH', 'SARAWAK', 'ZON BORNEO', 'KUALA LUMPUR', 'SELANGOR', 'ZON LEMBAH KLANG NEW']

# %% [markdown]
# <h1> Service Types </h1>

# %%
worksheet = book.sheet_by_index(0)
print("-----------------\n")
print("Service Type\n") 
print("-----------------\n")
serv_type = []
b = []
for a in worksheet.row_values(0):
  if(a!=""):
    serv_type.append(a.replace("\n"," "))
    b.append(a)
print(json.dumps(serv_type,indent=1))
# Out:
# -----------------
#
# Service Type
#
# -----------------
#
# [
#  "PHYSIOTHERAPY",
#  "OCCUPATIONAL THERAPY",
#  "SPEECH THERAPY",
#  "PSYCHOLOGY",
#  "CONSULTATION",
#  "ASSESSMENT & REPORT",
#  "FUNCTIONAL CAPACITY EVALUATION & REPORT",
#  "ADMINISTRATION SERVICES",
#  "HOSTEL",
#  "DRY NEEDLING/ ACUPUNCTURE",
#  "SERVICES BY MODALITIES",
#  "SERVICES BY PACKAGE"
# ]

# %% [markdown]
# <h2>Service Type To Service Code Mapping </h2>

# %%
# Instructions TO Use:
# Change from ("--Service Type Code\r\nSELECT * FROM BEAMS_DEV.REF_TABLE rt WHERE CODE_CATEGORY ='rtw_sp_serviceType'") to Service 
# -- Change the name of Parent Dictionary ['key'] as Service Type instead of the query i.e.,("--Service Type Code\r\nSELECT * FROM BEAMS_DEV.REF_TABLE rt WHERE CODE_CATEGORY ='rtw_sp_serviceType'")


with open('../JSON Strings/REF_TABLE__Service Type.json') as json_file: 
    data = json.load(json_file) 
# print(data["service type"])
print(json.dumps(data["service type"][0]["DESC_EN"],indent=1))
# Out:
# "PHYSIOTHERAPY"

# %%
def extract_service_type_refcode(serv_type):
    for i in data["service type"]:
        if(serv_type.lower() == i["DESC_EN"].lower()):
            # print("Service Type in DB = {} \n REF_CODE = {}".format(serv_type,i["REF_CODE"]))
            # print("----------------------------")
            return i["REF_CODE"]
            break

# %%
service_type_to_service_code = {}
count = 0
for i in serv_type:
    # print("----------------------------")
    # print("Service Type in Table= {}".format(i))
    service_type_to_service_code.update({i:extract_service_type_refcode(i)})
    count+=1
print(count)
print(json.dumps(service_type_to_service_code,indent=1))
# Out:
# 12
# {
#  "PHYSIOTHERAPY": "1",
#  "OCCUPATIONAL THERAPY": "2",
#  "SPEECH THERAPY": "4",
#  "PSYCHOLOGY": "6",
#  "CONSULTATION": "130",
#  "ASSESSMENT & REPORT": "129",
#  "FUNCTIONAL CAPACITY EVALUATION & REPORT": "128",
#  "ADMINISTRATION SERVICES": null,
#  "HOSTEL": null,
#  "DRY NEEDLING/ ACUPUNCTURE": null,
#  "SERVICES BY MODALITIES": null,
#  "SERVICES BY PACKAGE": null
# }

# %% [markdown]
# <h3> How Many Services Does a Service Type Has ? i.e., COLUMN COUNT FOR EACH SERVICE</h3>

# %%
print("-----------------\n")
print("SERV___COLUMNS\n") 
print("-----------------\n")
serv_columns = {}
col = [24,18,1,1,4,14,10,2,1,1,62,14]
for i in range(0,len(serv_type)):
   serv_columns.update({serv_type[i]:col[i]})
print(json.dumps(serv_columns,indent=1))
# Out:
# -----------------
#
# SERV___COLUMNS
#
# -----------------
#
# {
#  "PHYSIOTHERAPY": 24,
#  "OCCUPATIONAL THERAPY": 18,
#  "SPEECH THERAPY": 1,
#  "PSYCHOLOGY": 1,
#  "CONSULTATION": 4,
#  "ASSESSMENT & REPORT": 14,
#  "FUNCTIONAL CAPACITY EVALUATION & REPORT": 10,
#  "ADMINISTRATION SERVICES": 2,
#  "HOSTEL": 1,
#  "DRY NEEDLING/ ACUPUNCTURE": 1,
#  "SERVICES BY MODALITIES": 62,
#  "SERVICES BY PACKAGE": 14
# }

# %% [markdown]
# <h1> Services</h1>

# %%
print("-----------------\n")
print("Service\n") 
print("-----------------\n")
serv = []
for a in worksheet.row_values(1):
  if(a!=""):
    serv.append((a.replace("\n","")).strip())

# Removing Bil & Panel Treatment options
serv.pop(0)
serv.pop(0)
print(json.dumps(serv,indent=1))
# Out:
# -----------------
#
# Service
#
# -----------------
#
# [
#  "Physiotherapy Treatment",
#  "Manual Therapy",
#  "Pain Management",
#  "Musculoskeletal Rehabilitation",
#  "Sport Injuries Rehabilitation",
#  "Stroke rehabilitation",
#  "Spinal Cord Injury Rehabilitation",
#  "Traumatic Brain Injury Rehabilitation",
#  "Amputee Rehabilitation",
#  "Cardiorespiratory Rehabilitation",
#  "Hydrotherapy",
#  "Home Therapy + Mileage",
#  "Group Therapy And Exercises",
#  "Burn Management",
#  "Patient And Family Education Including Talk Workshop And Training",
#  "Women And Men Health",
#  "Other Neurological Or Rare Diseases Rehabilitation Such As Parkinson/Multiple Sclerosis/Muscular Dysthropy/Systemic Lupus/Ankylosing Spondylotis/Gullain Barre 1Syndrome",
#  "Alter-G (Anti Graviti) Physio",
#  "Tbion (Tibion Bionic Technology) Rehab",
#  "Chest Physiotherapy Manual",
#  "Chest Physiotherapy Suction Machine",
#  "Hand Function Training",
#  "Fine Motor Training",
#  "Cognitive Training",
#  "Occupational Therapy Treatment",
#  "Adl Training (Basic And Instrumental Adl)",
#  "Therapeutic Activities",
#  "Splinting",
#  "Pressure Garment",
#  "Cognitive And Perceptual Training",
#  "Ot Tx/ Therapeutic Exercise",
#  "Home Therapy + Mileage",
#  "Aids And Adaptations",
#  "Work Rehabilitation (Conditioning & Hardening)",
#  "Work Simulation Training / Work Hardening",
#  "Driving Training",
#  "Vehicle Modification",
#  "Functional Ergonomic Training",
#  "Mobility Training (Wheelchair/ Walking Aids/ Prosthetic Etc)",
#  "Patient And Family Education Including Talk Workshop And Training",
#  "Transitional Living Care Facility",
#  "Sensory Education",
#  "Speech TherapyTreatment",
#  "PsychologyTreatment",
#  "Rehab Specialist (Initial Session)",
#  "Rehab Specialist (Follow Up  Session)",
#  "Medical Officer(Initial Session)",
#  "Medical Officer (Follow Up Session)",
#  "General Pt  Assessment & Report",
#  "General Ot  Assessment & Report",
#  "Neuro/ Spinal Cord Injury Assessment & Report",
#  "Cognitive Assessment (Cognab)/ Perceptual Assessment & Repot",
#  "Home Modification Assessment & Report",
#  "Worksite Assessment & Report",
#  "Driving Assessment & Report",
#  "Wheelchair Assessment & Report",
#  "Prosthetic/ Amputation Assessment & Report",
#  "Speech Therapy Assessment & Report",
#  "Psychological Assessment & Report",
#  "Sensory Perception Test",
#  "Clinical Observation Neuromotor Performance",
#  "Visual Perception Test",
#  "General FCE & Report",
#  "Basic FCE",
#  "Complete FCE (BTE PRIMUS)",
#  "By Part FCE (BTE PRIMUS)",
#  "Upper extremity & hand FCE & Report",
#  "Trunk & lower extremity FCE & Report",
#  "Upper, Trunk, lower extremity FCE & Report",
#  "Neurological FCE & Report",
#  "Cardiopulmonary FCE & Report",
#  "Cognitive/ Perceptuan Function FCE & Report",
#  "First Registration Fees",
#  "Follow Up Registration Fess",
#  "Inpatient - Hostel & Makan",
#  "Dry Needling Package",
#  "Basic Equipment -Therapeutic Ultrasound",
#  "Basic Equipment - Hydrocollator pack",
#  "Basic Equipment - Tens",
#  "Basic Equipment -Cryocuff",
#  "Basic Equipment - Ice pack",
#  "Basic Equipment - Paraffin Wax",
#  "Basic Equipment - Dumb bell",
#  "Basic Equipment - Sandbag",
#  "Basic Equipment - Gym ball",
#  "Basic Equipment - Pulley",
#  "Basic Equipment - Wall bar",
#  "Basic Equipment - Parallel bar",
#  "Basic Equipment - Tilt Table",
#  "Basic Equipment - Plinth  and Bobath Plinth",
#  "Basic Equipment - Exercise Mat",
#  "Basic Equipment - Static cycle",
#  "Basic Equipment -Mechanical traction",
#  "Basic Equipment - Stairs",
#  "Basic Equipment - ADL kits",
#  "Basic Equipment - Fine motor kits",
#  "Basic Equipment - Splint",
#  "Basic Equipment - Pressure garment",
#  "Basic Equipment - Thera putty",
#  "Basic Equipment - Thera band",
#  "Basic Equipment - Hand exerciser equipment",
#  "Basic Equipment - SWD",
#  "Basic Equipment - Continuous Passive Machine",
#  "Basic Equipment - Interferential IFT",
#  "Basic Equipment - Ambulation",
#  "Basic Equipment - Hot Pack",
#  "Basic Equipment - Traction",
#  "Basic Equipment - Treadmill",
#  "Basic Equipment - Electrical Stimulation",
#  "Basic Equipment - Hydro Collator Pack",
#  "Basic Equipment - Infrared",
#  "Basic Equipment - Desensitisation Kit",
#  "Basic Equipment - Exercise In Gym",
#  "Basic Equipment - Hydro Collator Pack",
#  "Basic Equipment - Mobilizing Exercise",
#  "Advance Equipment - Multi gym equipment",
#  "Advance Equipment - Walking hoist",
#  "Advance Equipment - Biofeedback equipmentrd",
#  "Advance Equipment - Erigo stand",
#  "Advance Equipment - Armeo arm",
#  "Advance Equipment - Locomat",
#  "Advance Equipment - BTE Primus",
#  "Advance Equipment - BTE Evaltech",
#  "Advance Equipment - Vienna Test System",
#  "Advance Equipment - Lowenstein Occupational Therapy Cognitive Assessment (LOTCA) / Chessington Occupational Therapy Neurological Assessment (COTNAB)",
#  "Advance Equipment - Chessington Occupational Therapy Neurological Assessment (COTNAB)",
#  "Advance Equipment - Driving Simulator",
#  "Advance Equipment - T/PAL",
#  "Advance Equipment - Valpar",
#  "Advance Equipment - Laser \u2013 Low Intensity or High Intensity",
#  "Advance Equipment - Shock Wave Therapy",
#  "Advance Equipment - Short Wave Therapy",
#  "Advance Equipment - Magnetotherapy",
#  "Advance Equipment - Motomed",
#  "Advance Equipment - Hydro pool",
#  "Advance Equipment - Cybernic Rehab",
#  "Advance Equipment - Cryotherapy",
#  "Advance Equipment - Faradic",
#  "Pakej - Neuro Rehab",
#  "Pakej - Spine/Back Injury",
#  "Pakej - Neck Injury",
#  "Pakej - Shoulder Injury",
#  "Pakej - Hand Injury",
#  "Pakej - Knee Injury",
#  "Pakej - Fracture",
#  "Pakej - Pain Management",
#  "Pakej - Sport Rehab",
#  "Pakej - Cardiac Rehab",
#  "Pakej - General Exercise",
#  "Pakej - Respiratory Exercise",
#  "Pakej - 2 Electrical Modalities",
#  "Pakej - 3 Electrical Modalities/ More"
# ]

# %% [markdown]
# <h2>Service TO Service Code Mapping </h2>

# %%
with open('../JSON Strings/REF_TABLE__Service.json') as json_file: 
    data = json.load(json_file) 
# print(data["service type"])
print(json.dumps(data["service"][0]["DESC_EN"],indent=1))
# Out:
# "Manual Therapy"

# %%
def extract_service_refcode(serv):
    for i in data["service"]:
        if(serv.lower() == i["DESC_EN"].lower()):
            # print("Service Type in DB = {} \n REF_CODE = {}".format(serv_type,i["REF_CODE"]))
            # print("----------------------------")
            return i["REF_CODE"]
            break

# %%
service_to_service_code = {}
nulldata = {}
count = 0
for i in serv:
    a = extract_service_refcode(i)
    if(a==None):
        nulldata.update({i:a})
    else:
        service_to_service_code.update({i:a})
    count+=1
print(count)
print("\n------------------------------\n----- Ref Code Fetched ---- \n------------------------------\n{}".format(json.dumps(service_to_service_code,indent=1)))
print("\n------------------------------\n----- Null Data Fetched ---- \n------------------------------\n{}".format(json.dumps(nulldata,indent=1)))
# Out:
# 152
#
# ------------------------------
# ----- Ref Code Fetched ----
# ------------------------------
# {
#  "Manual Therapy": "1",
#  "Pain Management": "2",
#  "Musculoskeletal Rehabilitation": "3",
#  "Sport Injuries Rehabilitation": "4",
#  "Stroke rehabilitation": "5",
#  "Spinal Cord Injury Rehabilitation": "6",
#  "Traumatic Brain Injury Rehabilitation": "7",
#  "Amputee Rehabilitation": "8",
#  "Cardiorespiratory Rehabilitation": "9",
#  "Group Therapy And Exercises": "12",
#  "Burn Management": "13",
#  "Patient And Family Education Including Talk Workshop And Training": "14",
#  "Women And Men Health": "15",
#  "Adl Training (Basic And Instrumental Adl)": "17",
#  "Therapeutic Activities": "18",
#  "Splinting": "19",
#  "Pressure Garment": "20",
#  "Cognitive And Perceptual Training": "21",
#  "Aids And Adaptations": "23",
#  "Work Rehabilitation (Conditioning & Hardening)": "24",
#  "Driving Training": "26",
#  "Vehicle Modification": "27",
#  "Functional Ergonomic Training": "28",
#  "Mobility Training (Wheelchair/ Walking Aids/ Prosthetic Etc)": "29",
#  "Medical Officer(Initial Session)": "34",
#  "Neuro/ Spinal Cord Injury Assessment & Report": "39",
#  "Home Modification Assessment & Report": "41",
#  "Worksite Assessment & Report": "42",
#  "Driving Assessment & Report": "43",
#  "Wheelchair Assessment & Report": "44",
#  "Speech Therapy Assessment & Report": "46",
#  "Psychological Assessment & Report": "47",
#  "General FCE & Report": "48",
#  "Upper extremity & hand FCE & Report": "49",
#  "Trunk & lower extremity FCE & Report": "50",
#  "Upper, Trunk, lower extremity FCE & Report": "51",
#  "Neurological FCE & Report": "52",
#  "Cardiopulmonary FCE & Report": "53",
#  "Cognitive/ Perceptuan Function FCE & Report": "54"
# }
#
# ------------------------------
# ----- Null Data Fetched ----
# ------------------------------
# {
#  "Physiotherapy Treatment": null,
#  "Hydrotherapy": null,
#  "Home Therapy + Mileage": null,
#  "Other Neurological Or Rare Diseases Rehabilitation Such As Parkinson/Multiple Sclerosis/Muscular Dysthropy/Systemic Lupus/Ankylosing Spondylotis/Gullain Barre 1Syndrome": null,
#  "Alter-G (Anti Graviti) Physio": null,
#  "Tbion (Tibion Bionic Technology) Rehab": null,
#  "Chest Physiotherapy Manual": null,
#  "Chest Physiotherapy Suction Machine": null,
#  "Hand Function Training": null,
#  "Fine Motor Training": null,
#  "Cognitive Training": null,
#  "Occupational Therapy Treatment": null,
#  "Ot Tx/ Therapeutic Exercise": null,
#  "Work Simulation Training / Work Hardening": null,
#  "Transitional Living Care Facility": null,
#  "Sensory Education": null,
#  "Speech TherapyTreatment": null,
#  "PsychologyTreatment": null,
#  "Rehab Specialist (Initial Session)": null,
#  "Rehab Specialist (Follow Up  Session)": null,
#  "Medical Officer (Follow Up Session)": null,
#  "General Pt  Assessment & Report": null,
#  "General Ot  Assessment & Report": null,
#  "Cognitive Assessment (Cognab)/ Perceptual Assessment & Repot": null,
#  "Prosthetic/ Amputation Assessment & Report": null,
#  "Sensory Perception Test": null,
#  "Clinical Observation Neuromotor Performance": null,
#  "Visual Perception Test": null,
#  "Basic FCE": null,
#  "Complete FCE (BTE PRIMUS)": null,
#  "By Part FCE (BTE PRIMUS)": null,
#  "First Registration Fees": null,
#  "Follow Up Registration Fess": null,
#  "Inpatient - Hostel & Makan": null,
#  "Dry Needling Package": null,
#  "Basic Equipment -Therapeutic Ultrasound": null,
#  "Basic Equipment - Hydrocollator pack": null,
#  "Basic Equipment - Tens": null,
#  "Basic Equipment -Cryocuff": null,
#  "Basic Equipment - Ice pack": null,
#  "Basic Equipment - Paraffin Wax": null,
#  "Basic Equipment - Dumb bell": null,
#  "Basic Equipment - Sandbag": null,
#  "Basic Equipment - Gym ball": null,
#  "Basic Equipment - Pulley": null,
#  "Basic Equipment - Wall bar": null,
#  "Basic Equipment - Parallel bar": null,
#  "Basic Equipment - Tilt Table": null,
#  "Basic Equipment - Plinth  and Bobath Plinth": null,
#  "Basic Equipment - Exercise Mat": null,
#  "Basic Equipment - Static cycle": null,
#  "Basic Equipment -Mechanical traction": null,
#  "Basic Equipment - Stairs": null,
#  "Basic Equipment - ADL kits": null,
#  "Basic Equipment - Fine motor kits": null,
#  "Basic Equipment - Splint": null,
#  "Basic Equipment - Pressure garment": null,
#  "Basic Equipment - Thera putty": null,
#  "Basic Equipment - Thera band": null,
#  "Basic Equipment - Hand exerciser equipment": null,
#  "Basic Equipment - SWD": null,
#  "Basic Equipment - Continuous Passive Machine": null,
#  "Basic Equipment - Interferential IFT": null,
#  "Basic Equipment - Ambulation": null,
#  "Basic Equipment - Hot Pack": null,
#  "Basic Equipment - Traction": null,
#  "Basic Equipment - Treadmill": null,
#  "Basic Equipment - Electrical Stimulation": null,
#  "Basic Equipment - Hydro Collator Pack": null,
#  "Basic Equipment - Infrared": null,
#  "Basic Equipment - Desensitisation Kit": null,
#  "Basic Equipment - Exercise In Gym": null,
#  "Basic Equipment - Mobilizing Exercise": null,
#  "Advance Equipment - Multi gym equipment": null,
#  "Advance Equipment - Walking hoist": null,
#  "Advance Equipment - Biofeedback equipmentrd": null,
#  "Advance Equipment - Erigo stand": null,
#  "Advance Equipment - Armeo arm": null,
#  "Advance Equipment - Locomat": null,
#  "Advance Equipment - BTE Primus": null,
#  "Advance Equipment - BTE Evaltech": null,
#  "Advance Equipment - Vienna Test System": null,
#  "Advance Equipment - Lowenstein Occupational Therapy Cognitive Assessment (LOTCA) / Chessington Occupational Therapy Neurological Assessment (COTNAB)": null,
#  "Advance Equipment - Chessington Occupational Therapy Neurological Assessment (COTNAB)": null,
#  "Advance Equipment - Driving Simulator": null,
#  "Advance Equipment - T/PAL": null,
#  "Advance Equipment - Valpar": null,
#  "Advance Equipment - Laser \u2013 Low Intensity or High Intensity": null,
#  "Advance Equipment - Shock Wave Therapy": null,
#  "Advance Equipment - Short Wave Therapy": null,
#  "Advance Equipment - Magnetotherapy": null,
#  "Advance Equipment - Motomed": null,
#  "Advance Equipment - Hydro pool": null,
#  "Advance Equipment - Cybernic Rehab": null,
#  "Advance Equipment - Cryotherapy": null,
#  "Advance Equipment - Faradic": null,
#  "Pakej - Neuro Rehab": null,
#  "Pakej - Spine/Back Injury": null,
#  "Pakej - Neck Injury": null,
#  "Pakej - Shoulder Injury": null,
#  "Pakej - Hand Injury": null,
#  "Pakej - Knee Injury": null,
#  "Pakej - Fracture": null,
#  "Pakej - Pain Management": null,
#  "Pakej - Sport Rehab": null,
#  "Pakej - Cardiac Rehab": null,
#  "Pakej - General Exercise": null,
#  "Pakej - Respiratory Exercise": null,
#  "Pakej - 2 Electrical Modalities": null,
#  "Pakej - 3 Electrical Modalities/ More": null
# }

# %% [markdown]
# <h1>Mapping Hierarchy :-</h1>
# <h2>Panel & Service TO Service Type TO State Mapping  </h2>

# %%
d = []
panel = []
jsonfile = open("json_dump1.txt","w+")
data_file = open('../CSV Files/CSV_Data_v.5.csv', 'w+') 
  
# create the csv writer object 
csv_writer = csv.writer(data_file)

# %% [markdown]
# <h2> Panel to Panel Code Mapping</h2>

# %%
with open('../JSON Strings/REF_TABLE__Panel.json') as json_file: 
    data = json.load(json_file) 
# print(data["service type"])
print(json.dumps(data["panel"][0]["DESC_EN"],indent=1))
# Out:
# "SINAR REHABILITATION CENTRE (SEGAMAT)"

# %%
def extract_panel_refcode(panel_name):
    for i in data["panel"]:
        if(panel_name.lower() == i["DESC_EN"].lower()):
        # print("Service Type in DB = {} \n REF_CODE = {}".format(serv_type,i["REF_CODE"]))
        # print("----------------------------")
            return i["REF_CODE"]
            break

# %% [markdown]
# <h3>Price to Service Mapping </h3>

# %% [markdown]
# <h3>State Name TO Code Mapping <br> Zone Name TO Code Mapping</h3>

# %%
a = ["Johor","Kedah","Kelantan","Melaka","Negeri Sembilan","Pahang","Pulau Pinang","Perak","Perlis","Selangor","Terengganu","Sabah","Sarawak","Kuala Lumpur","Labuan","Putrajaya","N9","PP"]
b = ["ZON UTARA","ZON SELATAN","ZON TIMUR","ZON BORNEO","ZON TENGAH","ZON LEMBAH KLANG NEW"]

states_in_DB = {}
zones_in_DB = {}
for i in range(0,len(a)):
    states_in_DB.update({a[i].lower():int(i+1)})
for i in range(0,len(b)):
    zones_in_DB.update({b[i].lower():int(i+1)})
print(json.dumps(states_in_DB,indent=1))
print(json.dumps(zones_in_DB,indent=1))
# Out:
# {
#  "johor": 1,
#  "kedah": 2,
#  "kelantan": 3,
#  "melaka": 4,
#  "negeri sembilan": 5,
#  "pahang": 6,
#  "pulau pinang": 7,
#  "perak": 8,
#  "perlis": 9,
#  "selangor": 10,
#  "terengganu": 11,
#  "sabah": 12,
#  "sarawak": 13,
#  "kuala lumpur": 14,
#  "labuan": 15,
#  "putrajaya": 16,
#  "n9": 17,
#  "pp": 18
# }
# {
#  "zon utara": 1,
#  "zon selatan": 2,
#  "zon timur": 3,
#  "zon borneo": 4,
#  "zon tengah": 5,
#  "zon lembah klang new": 6
# }

# %%
def checkState(state_name):
    if state_name in states_in_DB:
        # print("State ={} , Value ={}".format(state_name,states_in_DB[state_name]))
        return states_in_DB[state_name]
    else:
        return -1
            
def checkZone(state_name):
    if state_name in zones_in_DB:
    #    print("Zone ={} , Value ={}".format(state_name,zones_in_DB[state_name]))
       return zones_in_DB[state_name]
    else:   
        return -2

# %%
# states=0
# zones=0
# for i in book.sheet_names():
#     a = checkZone(i.lower())
#     b = checkState(i.lower())
#     if(a==-2):
#         print(b)
#         states+=1

#     if(b==-1):
#         print(a)  
#         zones+=1
# print("States = {}".format(states))
# print("Zones = {}".format(zones))

# %%
def price(state_name,service_type,service,j,lower_bound,worksheet_no):
  c = {}
  d = []
  flag = False
  count=0
  worksheet = book.sheet_by_index(worksheet_no)
  for i in range(2,lower_bound):
    a = worksheet.cell_value(rowx=i,colx=j)
    b = worksheet.cell_value(rowx=i,colx=1)
    c.update({state_name:{service_type:{service:{b:a}}}})

    x = checkZone(state_name.lower())
    y = checkState(state_name.lower())
    z = extract_panel_refcode(b)
    # -------------------
    # Panel Mapping
    # -------------------

    # print("\n-------------------\nPanel Code Mapping\n-------------------\n")
    # print("Panel Name = {} \nPanel Code = {} -------------------\n".format(b,z))
    # if(count==0):
    panel.append({state_name:{b:z}})
    print(panel)
      # count+=1
    # -------------------
    # State Mapping
    # -------------------
    if(x==-2):
      d.append(y)
      d.append("")

    # -------------------
    # Zone Mapping
    # -------------------
    if(y==-1):
        d.append("")
        d.append(x)
    
    d.append(service_type.replace("\n", " "))
    d.append(service.replace("\n", " "))
    d.append(z)
    d.append(a)
    print("___________________")
    print("\t{}\t".format(d))
    print("___________________")
    csv_writer.writerow(d) 
    d = []
    return c

# %% [markdown]
# <h3> Service To Service Type Mapping<h3>

# %%
def service_to_service_type(state_name,lower_bound,worksheet_no):
  panel_to_serv_price = {}
  serv_to_serv_price = {}
  a = []
  panel_to_serv={}
  k = 2
  for key,value in serv_columns.items():
    for i in range(k,k+value):
      b = price(state_name,key,serv[i-2],i,lower_bound,worksheet_no)
      
      a.append(b)
    k = k + value
  panel_to_serv.update({state_name:a})
  return panel_to_serv

# %% [markdown]
# <h3>State To Service Type Mapping </h3>

# %%
print("------------------------------")
print("Final Data For Each Sheet")
print("------------------------------")
a = 0
final_result = []
sheet_column_count = {}
state_to_service = {}
for i in range(0,19):
    for j in (book.sheet_by_index(i)).col_values(1):
        if(j!=""):
            a+=1
    sheet_column_count.update({book.sheet_by_index(i).name:a-2})
    final_result.append(service_to_service_type(book.sheet_by_index(i).name,a-2,i))
    a=0
jsonfile.close()
file1 = open("json_dump1.txt","w+")
# print(json.dumps(final_result,indent=1))
file1.write(json.dumps(final_result, indent=1))
# Out:
# ------------------------------
# Final Data For Each Sheet
# ------------------------------
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Physiotherapy Treatment', '1', 80.0]
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Manual Therapy', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Pain Management', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Musculoskeletal Rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Sport Injuries Rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Stroke rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Spinal Cord Injury Rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Traumatic Brain Injury Rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Amputee Rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Cardiorespiratory Rehabilitation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Hydrotherapy', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Home Therapy + Mileage', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Group Therapy And Exercises', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Burn Management', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Patient And Family Education Including Talk Workshop And Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Women And Men Health', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Other Neurological Or Rare Diseases Rehabilitation Such As Parkinson/Multiple Sclerosis/Muscular Dysthropy/Systemic Lupus/Ankylosing Spondylotis/Gullain Barre 1Syndrome', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Alter-G (Anti Graviti) Physio', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Tbion (Tibion Bionic Technology) Rehab', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Chest Physiotherapy Manual', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Chest Physiotherapy Suction Machine', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Hand Function Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Fine Motor Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PHYSIOTHERAPY', 'Cognitive Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Occupational Therapy Treatment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Adl Training (Basic And Instrumental Adl)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Therapeutic Activities', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Splinting', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Pressure Garment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Cognitive And Perceptual Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Ot Tx/ Therapeutic Exercise', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Home Therapy + Mileage', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Aids And Adaptations', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Work Rehabilitation (Conditioning & Hardening)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Work Simulation Training / Work Hardening', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Driving Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Vehicle Modification', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Functional Ergonomic Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Mobility Training (Wheelchair/ Walking Aids/ Prosthetic Etc)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Patient And Family Education Including Talk Workshop And Training', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Transitional Living Care Facility', '1', '']
# ___________________
# ___________________
# 	[1, '', 'OCCUPATIONAL THERAPY', 'Sensory Education', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SPEECH THERAPY', 'Speech TherapyTreatment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'PSYCHOLOGY', 'PsychologyTreatment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'CONSULTATION', 'Rehab Specialist (Initial Session)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'CONSULTATION', 'Rehab Specialist (Follow Up  Session)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'CONSULTATION', 'Medical Officer(Initial Session)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'CONSULTATION', 'Medical Officer (Follow Up Session)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'General Pt  Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'General Ot  Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Neuro/ Spinal Cord Injury Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Cognitive Assessment (Cognab)/ Perceptual Assessment & Repot', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Home Modification Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Worksite Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Driving Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Wheelchair Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Prosthetic/ Amputation Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Speech Therapy Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Psychological Assessment & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Sensory Perception Test', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Clinical Observation Neuromotor Performance', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ASSESSMENT & REPORT', 'Visual Perception Test', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'General FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Basic FCE', '1', 95.0]
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Complete FCE (BTE PRIMUS)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'By Part FCE (BTE PRIMUS)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper extremity & hand FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Trunk & lower extremity FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper, Trunk, lower extremity FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Neurological FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cardiopulmonary FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cognitive/ Perceptuan Function FCE & Report', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ADMINISTRATION SERVICES', 'First Registration Fees', '1', '']
# ___________________
# ___________________
# 	[1, '', 'ADMINISTRATION SERVICES', 'Follow Up Registration Fess', '1', '']
# ___________________
# ___________________
# 	[1, '', 'HOSTEL', 'Inpatient - Hostel & Makan', '1', '']
# ___________________
# ___________________
# 	[1, '', 'DRY NEEDLING/ ACUPUNCTURE', 'Dry Needling Package', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Therapeutic Ultrasound', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydrocollator pack', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Tens', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Cryocuff', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Ice pack', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Paraffin Wax', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Dumb bell', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Sandbag', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Gym ball', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Pulley', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Wall bar', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Parallel bar', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Tilt Table', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Plinth  and Bobath Plinth', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise Mat', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Static cycle', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Mechanical traction', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Stairs', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - ADL kits', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Fine motor kits', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Splint', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Pressure garment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Thera putty', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Thera band', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hand exerciser equipment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - SWD', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Continuous Passive Machine', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Interferential IFT', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Ambulation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hot Pack', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Traction', '1', 53.0]
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Treadmill', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Electrical Stimulation', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydro Collator Pack', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Infrared', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Desensitisation Kit', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise In Gym', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydro Collator Pack', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Mobilizing Exercise', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Multi gym equipment', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Walking hoist', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Biofeedback equipmentrd', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Erigo stand', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Armeo arm', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Locomat', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - BTE Primus', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - BTE Evaltech', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Vienna Test System', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Lowenstein Occupational Therapy Cognitive Assessment (LOTCA) / Chessington Occupational Therapy Neurological Assessment (COTNAB)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Chessington Occupational Therapy Neurological Assessment (COTNAB)', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Driving Simulator', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - T/PAL', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Valpar', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Laser – Low Intensity or High Intensity', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Shock Wave Therapy', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Short Wave Therapy', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Magnetotherapy', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Motomed', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Hydro pool', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Cybernic Rehab', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Cryotherapy', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Faradic', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Neuro Rehab', '1', 45.0]
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Spine/Back Injury', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Neck Injury', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Shoulder Injury', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Hand Injury', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Knee Injury', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Fracture', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Pain Management', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Sport Rehab', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Cardiac Rehab', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - General Exercise', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - Respiratory Exercise', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - 2 Electrical Modalities', '1', '']
# ___________________
# ___________________
# 	[1, '', 'SERVICES BY PACKAGE', 'Pakej - 3 Electrical Modalities/ More', '1', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Physiotherapy Treatment', '15', 70.0]
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Manual Therapy', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Pain Management', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Musculoskeletal Rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Sport Injuries Rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Stroke rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Spinal Cord Injury Rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Traumatic Brain Injury Rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Amputee Rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Cardiorespiratory Rehabilitation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Hydrotherapy', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Home Therapy + Mileage', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Group Therapy And Exercises', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Burn Management', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Patient And Family Education Including Talk Workshop And Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Women And Men Health', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Other Neurological Or Rare Diseases Rehabilitation Such As Parkinson/Multiple Sclerosis/Muscular Dysthropy/Systemic Lupus/Ankylosing Spondylotis/Gullain Barre 1Syndrome', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Alter-G (Anti Graviti) Physio', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Tbion (Tibion Bionic Technology) Rehab', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Chest Physiotherapy Manual', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Chest Physiotherapy Suction Machine', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Hand Function Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Fine Motor Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PHYSIOTHERAPY', 'Cognitive Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Occupational Therapy Treatment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Adl Training (Basic And Instrumental Adl)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Therapeutic Activities', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Splinting', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Pressure Garment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Cognitive And Perceptual Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Ot Tx/ Therapeutic Exercise', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Home Therapy + Mileage', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Aids And Adaptations', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Work Rehabilitation (Conditioning & Hardening)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Work Simulation Training / Work Hardening', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Driving Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Vehicle Modification', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Functional Ergonomic Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Mobility Training (Wheelchair/ Walking Aids/ Prosthetic Etc)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Patient And Family Education Including Talk Workshop And Training', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Transitional Living Care Facility', '15', '']
# ___________________
# ___________________
# 	[4, '', 'OCCUPATIONAL THERAPY', 'Sensory Education', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SPEECH THERAPY', 'Speech TherapyTreatment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'PSYCHOLOGY', 'PsychologyTreatment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'CONSULTATION', 'Rehab Specialist (Initial Session)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'CONSULTATION', 'Rehab Specialist (Follow Up  Session)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'CONSULTATION', 'Medical Officer(Initial Session)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'CONSULTATION', 'Medical Officer (Follow Up Session)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'General Pt  Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'General Ot  Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Neuro/ Spinal Cord Injury Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Cognitive Assessment (Cognab)/ Perceptual Assessment & Repot', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Home Modification Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Worksite Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Driving Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Wheelchair Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Prosthetic/ Amputation Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Speech Therapy Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Psychological Assessment & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Sensory Perception Test', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Clinical Observation Neuromotor Performance', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ASSESSMENT & REPORT', 'Visual Perception Test', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'General FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Basic FCE', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Complete FCE (BTE PRIMUS)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'By Part FCE (BTE PRIMUS)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper extremity & hand FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Trunk & lower extremity FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper, Trunk, lower extremity FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Neurological FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cardiopulmonary FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cognitive/ Perceptuan Function FCE & Report', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ADMINISTRATION SERVICES', 'First Registration Fees', '15', '']
# ___________________
# ___________________
# 	[4, '', 'ADMINISTRATION SERVICES', 'Follow Up Registration Fess', '15', '']
# ___________________
# ___________________
# 	[4, '', 'HOSTEL', 'Inpatient - Hostel & Makan', '15', '']
# ___________________
# ___________________
# 	[4, '', 'DRY NEEDLING/ ACUPUNCTURE', 'Dry Needling Package', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Therapeutic Ultrasound', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydrocollator pack', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Tens', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Cryocuff', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Ice pack', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Paraffin Wax', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Dumb bell', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Sandbag', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Gym ball', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Pulley', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Wall bar', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Parallel bar', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Tilt Table', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Plinth  and Bobath Plinth', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise Mat', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Static cycle', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Mechanical traction', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Stairs', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - ADL kits', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Fine motor kits', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Splint', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Pressure garment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Thera putty', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Thera band', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hand exerciser equipment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - SWD', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Continuous Passive Machine', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Interferential IFT', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Ambulation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hot Pack', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Traction', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Treadmill', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Electrical Stimulation', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydro Collator Pack', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Infrared', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Desensitisation Kit', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise In Gym', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydro Collator Pack', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Mobilizing Exercise', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Multi gym equipment', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Walking hoist', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Biofeedback equipmentrd', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Erigo stand', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Armeo arm', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Locomat', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - BTE Primus', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - BTE Evaltech', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Vienna Test System', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Lowenstein Occupational Therapy Cognitive Assessment (LOTCA) / Chessington Occupational Therapy Neurological Assessment (COTNAB)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Chessington Occupational Therapy Neurological Assessment (COTNAB)', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Driving Simulator', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - T/PAL', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Valpar', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Laser – Low Intensity or High Intensity', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Shock Wave Therapy', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Short Wave Therapy', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Magnetotherapy', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Motomed', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Hydro pool', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Cybernic Rehab', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Cryotherapy', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY MODALITIES', 'Advance Equipment - Faradic', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Neuro Rehab', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Spine/Back Injury', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Neck Injury', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Shoulder Injury', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Hand Injury', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Knee Injury', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Fracture', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Pain Management', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Sport Rehab', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Cardiac Rehab', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - General Exercise', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - Respiratory Exercise', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - 2 Electrical Modalities', '15', '']
# ___________________
# ___________________
# 	[4, '', 'SERVICES BY PACKAGE', 'Pakej - 3 Electrical Modalities/ More', '15', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Physiotherapy Treatment', '17', 90.0]
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Manual Therapy', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Pain Management', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Musculoskeletal Rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Sport Injuries Rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Stroke rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Spinal Cord Injury Rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Traumatic Brain Injury Rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Amputee Rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Cardiorespiratory Rehabilitation', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Hydrotherapy', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Home Therapy + Mileage', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Group Therapy And Exercises', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Burn Management', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Patient And Family Education Including Talk Workshop And Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Women And Men Health', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Other Neurological Or Rare Diseases Rehabilitation Such As Parkinson/Multiple Sclerosis/Muscular Dysthropy/Systemic Lupus/Ankylosing Spondylotis/Gullain Barre 1Syndrome', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Alter-G (Anti Graviti) Physio', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Tbion (Tibion Bionic Technology) Rehab', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Chest Physiotherapy Manual', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Chest Physiotherapy Suction Machine', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Hand Function Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Fine Motor Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PHYSIOTHERAPY', 'Cognitive Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Occupational Therapy Treatment', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Adl Training (Basic And Instrumental Adl)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Therapeutic Activities', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Splinting', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Pressure Garment', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Cognitive And Perceptual Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Ot Tx/ Therapeutic Exercise', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Home Therapy + Mileage', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Aids And Adaptations', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Work Rehabilitation (Conditioning & Hardening)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Work Simulation Training / Work Hardening', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Driving Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Vehicle Modification', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Functional Ergonomic Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Mobility Training (Wheelchair/ Walking Aids/ Prosthetic Etc)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Patient And Family Education Including Talk Workshop And Training', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Transitional Living Care Facility', '17', '']
# ___________________
# ___________________
# 	[17, '', 'OCCUPATIONAL THERAPY', 'Sensory Education', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SPEECH THERAPY', 'Speech TherapyTreatment', '17', '']
# ___________________
# ___________________
# 	[17, '', 'PSYCHOLOGY', 'PsychologyTreatment', '17', '']
# ___________________
# ___________________
# 	[17, '', 'CONSULTATION', 'Rehab Specialist (Initial Session)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'CONSULTATION', 'Rehab Specialist (Follow Up  Session)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'CONSULTATION', 'Medical Officer(Initial Session)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'CONSULTATION', 'Medical Officer (Follow Up Session)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'General Pt  Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'General Ot  Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Neuro/ Spinal Cord Injury Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Cognitive Assessment (Cognab)/ Perceptual Assessment & Repot', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Home Modification Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Worksite Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Driving Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Wheelchair Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Prosthetic/ Amputation Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Speech Therapy Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Psychological Assessment & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Sensory Perception Test', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Clinical Observation Neuromotor Performance', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ASSESSMENT & REPORT', 'Visual Perception Test', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'General FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Basic FCE', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Complete FCE (BTE PRIMUS)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'By Part FCE (BTE PRIMUS)', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper extremity & hand FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Trunk & lower extremity FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper, Trunk, lower extremity FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Neurological FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cardiopulmonary FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cognitive/ Perceptuan Function FCE & Report', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ADMINISTRATION SERVICES', 'First Registration Fees', '17', '']
# ___________________
# ___________________
# 	[17, '', 'ADMINISTRATION SERVICES', 'Follow Up Registration Fess', '17', '']
# ___________________
# ___________________
# 	[17, '', 'HOSTEL', 'Inpatient - Hostel & Makan', '17', '']
# ___________________
# ___________________
# 	[17, '', 'DRY NEEDLING/ ACUPUNCTURE', 'Dry Needling Package', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Therapeutic Ultrasound', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Hydrocollator pack', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Tens', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Cryocuff', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Ice pack', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Paraffin Wax', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Dumb bell', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Sandbag', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Gym ball', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Pulley', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Wall bar', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Parallel bar', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Tilt Table', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Plinth  and Bobath Plinth', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise Mat', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Static cycle', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment -Mechanical traction', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Stairs', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - ADL kits', '17', '']
# ___________________
# ___________________
# 	[17, '', 'SERVICES BY MODALITIES', 'Basic Equipment - Fine motor kits', '17', '']
# ___________________
# ...
# ___________________
# 	['', 6, 'PHYSIOTHERAPY', 'Chest Physiotherapy Suction Machine', '84', '']
# ___________________
# ___________________
# 	['', 6, 'PHYSIOTHERAPY', 'Hand Function Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'PHYSIOTHERAPY', 'Fine Motor Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'PHYSIOTHERAPY', 'Cognitive Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Occupational Therapy Treatment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Adl Training (Basic And Instrumental Adl)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Therapeutic Activities', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Splinting', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Pressure Garment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Cognitive And Perceptual Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Ot Tx/ Therapeutic Exercise', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Home Therapy + Mileage', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Aids And Adaptations', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Work Rehabilitation (Conditioning & Hardening)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Work Simulation Training / Work Hardening', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Driving Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Vehicle Modification', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Functional Ergonomic Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Mobility Training (Wheelchair/ Walking Aids/ Prosthetic Etc)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Patient And Family Education Including Talk Workshop And Training', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Transitional Living Care Facility', '84', '']
# ___________________
# ___________________
# 	['', 6, 'OCCUPATIONAL THERAPY', 'Sensory Education', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SPEECH THERAPY', 'Speech TherapyTreatment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'PSYCHOLOGY', 'PsychologyTreatment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'CONSULTATION', 'Rehab Specialist (Initial Session)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'CONSULTATION', 'Rehab Specialist (Follow Up  Session)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'CONSULTATION', 'Medical Officer(Initial Session)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'CONSULTATION', 'Medical Officer (Follow Up Session)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'General Pt  Assessment & Report', '84', 195.0]
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'General Ot  Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Neuro/ Spinal Cord Injury Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Cognitive Assessment (Cognab)/ Perceptual Assessment & Repot', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Home Modification Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Worksite Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Driving Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Wheelchair Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Prosthetic/ Amputation Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Speech Therapy Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Psychological Assessment & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Sensory Perception Test', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Clinical Observation Neuromotor Performance', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ASSESSMENT & REPORT', 'Visual Perception Test', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'General FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Basic FCE', '84', 220.0]
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Complete FCE (BTE PRIMUS)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'By Part FCE (BTE PRIMUS)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper extremity & hand FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Trunk & lower extremity FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Upper, Trunk, lower extremity FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Neurological FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cardiopulmonary FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'Cognitive/ Perceptuan Function FCE & Report', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ADMINISTRATION SERVICES', 'First Registration Fees', '84', '']
# ___________________
# ___________________
# 	['', 6, 'ADMINISTRATION SERVICES', 'Follow Up Registration Fess', '84', '']
# ___________________
# ___________________
# 	['', 6, 'HOSTEL', 'Inpatient - Hostel & Makan', '84', '']
# ___________________
# ___________________
# 	['', 6, 'DRY NEEDLING/ ACUPUNCTURE', 'Dry Needling Package', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment -Therapeutic Ultrasound', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Hydrocollator pack', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Tens', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment -Cryocuff', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Ice pack', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Paraffin Wax', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Dumb bell', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Sandbag', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Gym ball', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Pulley', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Wall bar', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Parallel bar', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Tilt Table', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Plinth  and Bobath Plinth', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise Mat', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Static cycle', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment -Mechanical traction', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Stairs', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - ADL kits', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Fine motor kits', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Splint', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Pressure garment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Thera putty', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Thera band', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Hand exerciser equipment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - SWD', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Continuous Passive Machine', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Interferential IFT', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Ambulation', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Hot Pack', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Traction', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Treadmill', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Electrical Stimulation', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Hydro Collator Pack', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Infrared', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Desensitisation Kit', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Exercise In Gym', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Hydro Collator Pack', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Basic Equipment - Mobilizing Exercise', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Multi gym equipment', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Walking hoist', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Biofeedback equipmentrd', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Erigo stand', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Armeo arm', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Locomat', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - BTE Primus', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - BTE Evaltech', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Vienna Test System', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Lowenstein Occupational Therapy Cognitive Assessment (LOTCA) / Chessington Occupational Therapy Neurological Assessment (COTNAB)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Chessington Occupational Therapy Neurological Assessment (COTNAB)', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Driving Simulator', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - T/PAL', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Valpar', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Laser – Low Intensity or High Intensity', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Shock Wave Therapy', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Short Wave Therapy', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Magnetotherapy', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Motomed', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Hydro pool', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Cybernic Rehab', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Cryotherapy', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY MODALITIES', 'Advance Equipment - Faradic', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Neuro Rehab', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Spine/Back Injury', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Neck Injury', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Shoulder Injury', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Hand Injury', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Knee Injury', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Fracture', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Pain Management', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Sport Rehab', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Cardiac Rehab', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - General Exercise', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - Respiratory Exercise', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - 2 Electrical Modalities', '84', '']
# ___________________
# ___________________
# 	['', 6, 'SERVICES BY PACKAGE', 'Pakej - 3 Electrical Modalities/ More', '84', '']
# ___________________
# 494652

# %%
for j in book.sheet_names():
    for i in panel:
        print(i)
        print(i[j])
# Out:
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'JOHOR': {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}}
# {'SINAR REHABILITATION CENTRE (SEGAMAT)': '1'}
# {'MELAKA': {'TAGS SPINE & JOINT SPECIALISTS (MELAKA)': '15'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-c7c3a96b9eef> in <module>
#       2     for i in panel:
#       3         print(i)
# ----> 4         print(i[j])
#
# KeyError: 'JOHOR'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-d0169b09db5d> in <module>
# ----> 1 panel["MELAKA"]
#
# TypeError: list indices must be integers or slices, not str
