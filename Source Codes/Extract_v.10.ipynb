# %%
import xlrd 
import json
import csv
import codecs
import sys
# from google.colab import files
# uploaded = files.upload()

# %%
book = xlrd.open_workbook("../RTW.xls")
worksheet = book.sheet_by_index(0)

# %%
print("The number of worksheets is {0}".format(book.nsheets))
print("Worksheet name(s): {0}".format(book.sheet_names()))
# Out:
# The number of worksheets is 19
# Worksheet name(s): ['JOHOR', 'MELAKA', 'N9', 'ZON SELATAN', 'PERLIS', 'KEDAH', 'PP', 'PERAK', 'ZON UTARA', 'PAHANG', 'KELANTAN', 'TERENGGANU', 'ZON TIMUR', 'SABAH', 'SARAWAK', 'ZON BORNEO', 'KUALA LUMPUR', 'SELANGOR', 'ZON LEMBAH KLANG NEW']

# %% [markdown]
# <h1> Service Types </h1>

# %%
data = open('Service Type.txt', 'r') 
serv_type = []
serv_type_og = []
service_type_to_service_code = {}
count = 0
for i in data:
    count+=1
    serv_type.append(i.strip("\n"))
    serv_type_og.append(i.strip("\n"))
print(serv_type)
# Out:
# ['PHYSIOTHERAPY', 'OCCUPATIONAL THERAPY', 'SPEECH THERAPY', 'FUNCTIONAL CAPACITY EVALUATION & REPORT', 'SERVICES BY PACKAGE', 'ASSESSMENT & REPORT', 'DRY NEEDLING/ACUPUNCTURE', 'SERVICES BY MODALITIES', 'CONSULTATION', 'HOSTEL', 'PSYCHOLOGY', 'ADMINISTRATION SERVICES']

# %%
print("-----------------\n")
print("Service Type TO Service Code Mapping\n") 
print("-----------------\n")
service_type_to_service_code = {}
service_type_to_service_code_og = {}
count = 0
for i in serv_type:
    if(i.lower()=="services by package"):
        a = "serv_by_pack"
    elif(i.lower()=="services by modalities"):
        a = "serv_by_mod"
    else:
        a = i.lower()[0:3]
    service_type_to_service_code.update({(i.lower()).replace(' ',""):"rtw_st_"+a})
    service_type_to_service_code_og.update({i:"rtw_st_"+a})
    # service_type_to_service_code_without_spaces({})
print(json.dumps(service_type_to_service_code_og,indent=1))
# Out:
# -----------------
#
# Service Type TO Service Code Mapping
#
# -----------------
#
# {
#  "PHYSIOTHERAPY": "rtw_st_phy",
#  "OCCUPATIONAL THERAPY": "rtw_st_occ",
#  "SPEECH THERAPY": "rtw_st_spe",
#  "FUNCTIONAL CAPACITY EVALUATION & REPORT": "rtw_st_fun",
#  "SERVICES BY PACKAGE": "rtw_st_serv_by_pack",
#  "ASSESSMENT & REPORT": "rtw_st_ass",
#  "DRY NEEDLING/ACUPUNCTURE": "rtw_st_dry",
#  "SERVICES BY MODALITIES": "rtw_st_serv_by_mod",
#  "CONSULTATION": "rtw_st_con",
#  "HOSTEL": "rtw_st_hos",
#  "PSYCHOLOGY": "rtw_st_psy",
#  "ADMINISTRATION SERVICES": "rtw_st_adm"
# }

# %%
def get_service_type_code(i):
    i = (i.replace(' ',"")).lower()
    if i in service_type_to_service_code:
        return service_type_to_service_code[i]

# %% [markdown]
# <h3> How Many Services Does a Service Type Has ? i.e., COLUMN COUNT FOR EACH SERVICE</h3>

# %%
print("-----------------\n")
print("SERV___COLUMNS\n") 
print("-----------------\n")
serv_columns = {}
col = [24,18,1,1,4,14,10,2,1,1,62,14]
for i in range(0,len(serv_type)):
   serv_columns.update({serv_type[i]:col[i]})
print(json.dumps(serv_columns,indent=1))
# Out:
# -----------------
#
# SERV___COLUMNS
#
# -----------------
#
# {
#  "PHYSIOTHERAPY": 24,
#  "OCCUPATIONAL THERAPY": 18,
#  "SPEECH THERAPY": 1,
#  "FUNCTIONAL CAPACITY EVALUATION & REPORT": 1,
#  "SERVICES BY PACKAGE": 4,
#  "ASSESSMENT & REPORT": 14,
#  "DRY NEEDLING/ACUPUNCTURE": 10,
#  "SERVICES BY MODALITIES": 2,
#  "CONSULTATION": 1,
#  "HOSTEL": 1,
#  "PSYCHOLOGY": 62,
#  "ADMINISTRATION SERVICES": 14
# }

# %% [markdown]
# <h1> Services</h1>

# %%
print("Services From Appendix Sheet")
data = open('appendix_sheet.txt', 'r') 
serv = []
serv_og = []
count=0
for i in data:
    count+=1
    s1 = ((i.strip("\n")).lower()).replace(" ","")
    s2 = ((i.strip("\n")))
    serv.append(s1)
    serv_og.append(s2)
print(serv_og)
# Out:
# Services From Appendix Sheet
# ...

# %%
print("Services From RTW Sheet")
servi = []
servi_og = []
for a in worksheet.row_values(1):
  if(a!=""):
    count+=1
    s = ((a.replace("\n","")).strip()).replace(' ',"")
    s = s.lower()
    servi_og.append(a)
    servi.append(s.lower())
    if not s in serv:
      serv.append(s)
      serv_og.append(a)

# Extra Data Which Was Coming Null in the DB
serv.append("physiotherapytreatment(outpatient)")
serv_og.append("Physiotherapy Treatment (outpatient)")
# Removing Bil & Panel Treatment options
servi.pop(0)
servi.pop(0)
print(count)
# print(json.dumps(servi,indent=1))
# Out:
# Services From RTW Sheet
# 305

# %%
count = 0
for i in serv:
    count+=1
print(count)
print(json.dumps(serv,indent=1))
# Out:
# 223
# [
#  "physiotherapytreatment",
#  "manualtherapy",
#  "painmanagement",
#  "musculoskeletalrehabilitation",
#  "sportinjuriesrehabilitation",
#  "strokerehabilitation",
#  "spinalcordinjuryrehabilitation",
#  "traumaticbraininjuryrehabilitation",
#  "amputeerehabilitation",
#  "cardiorespiratoryrehabilitation",
#  "hydrotherapy",
#  "hometherapy+mileage",
#  "grouptherapyandexercises",
#  "burnmanagement",
#  "patientandfamilyeducationincludingtalkworkshopandtraining",
#  "womenandmenhealth",
#  "otherneurologicalorrarediseasesrehabilitationsuchasparkinson/multiplesclerosis/musculardysthropy/systemiclupus/ankylosingspondylotis/gullainbarre1syndrome",
#  "alter-g(antigraviti)physio",
#  "tbion(tibionbionictechnology)rehab",
#  "chestphysiotherapymanual",
#  "chestphysiotherapysuctionmachine",
#  "handfunctiontraining",
#  "finemotortraining",
#  "cognitivetraining",
#  "occupationaltherapytreatment",
#  "adltraining(basicandinstrumentaladl)",
#  "therapeuticactivities",
# ...

# %%
print("-----------------\n")
print("Service TO Service Code Mapping\n") 
print("-----------------\n")
service_to_service_code_og = {}
a = []
z = 0
for i in serv_og:
    z+=1
    s = ("rtw_s"+str(z)+"_"+i.lower()[0:3]).strip()
    service_to_service_code_og.update({i:s})
print(json.dumps(service_to_service_code_og,indent=1))
# Out:
# -----------------
#
# Service TO Service Code Mapping
#
# -----------------
#
# {
#  "Physiotherapy Treatment": "rtw_s1_phy",
#  "Manual Therapy": "rtw_s2_man",
#  "Pain Management": "rtw_s3_pai",
#  "Musculoskeletal Rehabilitation": "rtw_s4_mus",
#  "Sport Injuries Rehabilitation": "rtw_s5_spo",
#  "Stroke Rehabilitation": "rtw_s6_str",
#  "Spinal Cord Injury Rehabilitation": "rtw_s7_spi",
#  "Traumatic Brain Injury Rehabilitation": "rtw_s8_tra",
#  "Amputee Rehabilitation": "rtw_s9_amp",
#  "Cardiorespiratory Rehabilitation": "rtw_s10_car",
#  "Hydrotherapy": "rtw_s11_hyd",
#  "Home Therapy + Mileage": "rtw_s32_hom",
#  "Group Therapy And Exercises": "rtw_s13_gro",
#  "Burn Management": "rtw_s14_bur",
#  "Patient And Family Education Including Talk Workshop And Training": "rtw_s40_pat",
#  "Women And Men Health": "rtw_s16_wom",
# ...

# %%
print("-----------------\n")
print("Service TO Service Code Mapping\n") 
print("-----------------\n")
service_to_service_code = {}
a = []
z = 0
for i in serv:
    z+=1
    s = ("rtw_s"+str(z)+"_"+i.lower()[0:3]).strip()
    service_to_service_code.update({i:s})
print(json.dumps(service_to_service_code,indent=1))
# Out:
# -----------------
#
# Service TO Service Code Mapping
#
# -----------------
#
# {
#  "physiotherapytreatment": "rtw_s1_phy",
#  "manualtherapy": "rtw_s2_man",
#  "painmanagement": "rtw_s3_pai",
#  "musculoskeletalrehabilitation": "rtw_s4_mus",
#  "sportinjuriesrehabilitation": "rtw_s5_spo",
#  "strokerehabilitation": "rtw_s6_str",
#  "spinalcordinjuryrehabilitation": "rtw_s7_spi",
#  "traumaticbraininjuryrehabilitation": "rtw_s8_tra",
#  "amputeerehabilitation": "rtw_s9_amp",
#  "cardiorespiratoryrehabilitation": "rtw_s10_car",
#  "hydrotherapy": "rtw_s11_hyd",
#  "hometherapy+mileage": "rtw_s32_hom",
#  "grouptherapyandexercises": "rtw_s13_gro",
#  "burnmanagement": "rtw_s14_bur",
#  "patientandfamilyeducationincludingtalkworkshopandtraining": "rtw_s40_pat",
#  "womenandmenhealth": "rtw_s16_wom",
#  "otherneurologicalorrarediseasesrehabilitationsuchasparkinson/multiplesclerosis/musculardysthropy/systemiclupus/ankylosingspondylotis/gullainbarre1syndrome": "rtw_s17_oth",
# ...

# %%
def get_service_code(i):
    i = (i.replace(' ',"")).lower()
    if(i=="Advance Equipment - Laser – Low Intensity or High Intensity"):
        return "rtw_s49_adv"
    if i.replace(' ',"") in service_to_service_code:
        return service_to_service_code[i]

# %%
print(json.dumps(service_to_service_code,indent=1))
# Out:
# {
#  "physiotherapytreatment": "rtw_s1_phy",
#  "manualtherapy": "rtw_s2_man",
#  "painmanagement": "rtw_s3_pai",
#  "musculoskeletalrehabilitation": "rtw_s4_mus",
#  "sportinjuriesrehabilitation": "rtw_s5_spo",
#  "strokerehabilitation": "rtw_s6_str",
#  "spinalcordinjuryrehabilitation": "rtw_s7_spi",
#  "traumaticbraininjuryrehabilitation": "rtw_s8_tra",
#  "amputeerehabilitation": "rtw_s9_amp",
#  "cardiorespiratoryrehabilitation": "rtw_s10_car",
#  "hydrotherapy": "rtw_s11_hyd",
#  "hometherapy+mileage": "rtw_s32_hom",
#  "grouptherapyandexercises": "rtw_s13_gro",
#  "burnmanagement": "rtw_s14_bur",
#  "patientandfamilyeducationincludingtalkworkshopandtraining": "rtw_s40_pat",
#  "womenandmenhealth": "rtw_s16_wom",
#  "otherneurologicalorrarediseasesrehabilitationsuchasparkinson/multiplesclerosis/musculardysthropy/systemiclupus/ankylosingspondylotis/gullainbarre1syndrome": "rtw_s17_oth",
#  "alter-g(antigraviti)physio": "rtw_s18_alt",
# ...

# %%
i = ("COLUMBIA ASIA HOSPITAL \u2013 PUCHONG (PUCHONG)".encode('ascii', 'ignore')).decode("utf-8")
print(i)
# Out:
# COLUMBIA ASIA HOSPITAL  PUCHONG (PUCHONG)

# %%
# print("-----------------------------")
# print("Panel TO Panel Code Mapping")
# print("-----------------------------")
# data = codecs.open('panel.txt', 'r','utf-8') 
# panel_code = {}
# # serv_og = []
# count=0
# for i in data:
#     i = i.replace("\n","")
#     i = i.replace("\r","")
#     # i = (i.encode('ascii', 'ignore')).decode("utf-8")
#     count+=1
#     # if(panel[i[]=="rtw_COLUMBIA_PUCHONG"):
#     #     print("_____________________")
#     #     print(panel)
#     #     print("_____________________")
#     if(i.find("(")==-1):
#         s = s + "rtw"+"_"+(i.split(' '))[0]
#     else:
#         s = s + "rtw"+"_"+(i.split(' '))[0] +"_"+ i[i.find("(")+1:i.find(")")]
#     panel_code.update({str(i):s})
#     s=""
# print(json.dumps(panel_code,indent=1))

# %%
panel_code = {"SINAR REHABILITATION CENTRE (SEGAMAT)": "rtw_SINAR_SEGAMAT",
 "REHAB HEALTHCARE SDN BHD (KLUANG)": "rtw_REHAB_KLUANG",
 "KLUANG UTAMA SPECIALIST HOSPITAL (KLUANG)": "rtw_KLUANG_KLUANG",
 "JB PHYSIOTHERAPY SDN BHD (JB)": "rtw_JB_JB",
 "GREAT LIFE PHYSIO & REHABILITATION (JB)": "rtw_GREAT_JB",
 "BP PHYSIOTHERAPY CENTRE (BATU PAHAT)": "rtw_BP_BATU PAHAT",
 "TAGS SPINE & JOINT SPECIALISTS (JB)": "rtw_TAGS_JB",
 "EPISODE FISIOTERAPI DAN PEMULIHAN (BATU PAHAT)": "rtw_EPISODE_BATU PAHAT",
 "PANTAI INTEGRATED REHAB SERVICES SDN BHD, HOSPITAL PANTAI BATU PAHAT": "rtw_PANTAI",
 "PHYSIOMOBILEMY SERVICES, PMMY GROUP SDN BHD (JB)": "rtw_PHYSIOMOBILEMY_JB",
 "HMC PROVIDERS SDN BHD (SHAH ALAM)": "rtw_HMC_SHAH ALAM",
 "TAGS SPINE & JOINT SPECIALISTS (MELAKA)": "rtw_TAGS_MELAKA",
 "EZ PHYSIOTHERAPY CENTER (MELAKA)": "rtw_EZ_MELAKA",
 "NSCMH MEDICAL CENTRE (SEREMBAN)": "rtw_NSCMH_SEREMBAN",
 "SALAM SENAWANG SPECIALIST CENTRE (SENAWANG)": "rtw_SALAM_SENAWANG",
 "TAGS SPINE & JOINT SPECIALISTS (SEREMBAN)": "rtw_TAGS_SEREMBAN",
 "BAINS PHYSIO, BAINS THERAPEUTICS CENTRE SDN BHD (NILAI)": "rtw_BAINS_NILAI",
 "KPJ SEREMBAN SPECIALIST HOSPITAL (SEREMBAN)": "rtw_KPJ_SEREMBAN",
 "SE SENAWANG PHYSIOTHERAPY & HOME REHAB CENTRE": "rtw_SE",
 "APOLLO PHYSIOTHERAPY CENTRE": "rtw_APOLLO",
 "DOCUMENTATION BASED CARE (DBC ALOR SETAR)": "rtw_DOCUMENTATION_DBC ALOR SETAR",
 "LIFECARE PHYSIOTHERAPY CENTRE (SUNGAI PETANI)": "rtw_LIFECARE_SUNGAI PETANI",
 "MEDYNA PHYSIO AND REHAB SERVICES (ALOR SETAR)": "rtw_MEDYNA_ALOR SETAR",
 "LANGKAWAI PHYSIOTHERAPY CENTRE (LANGKAWI)": "rtw_LANGKAWAI_LANGKAWI",
 "PHYSIOTHERAPY KULIM CENTRE (KULIM)": "rtw_PHYSIOTHERAPY_KULIM",
 "BAINS PHYSIO (ALOR SETAR)": "rtw_BAINS_ALOR SETAR",
 "PUSAT RAWATAN FISIOTERAPI IMPIANA": "rtw_PUSAT",
 "WELL PHYSIO SDN BHD (BUKIT MERTAJAM)": "rtw_WELL_BUKIT MERTAJAM",
 "DEE B.M. PHYSIOTHERAPY & REHABILITATION CENTRE (BUKIT MERTAJAM)": "rtw_DEE_BUKIT MERTAJAM",
 "TAGS SPINE & JOINT SPECIALISTS (PENANG) - BAYAN LEPAS": "rtw_TAGS_PENANG",
 "RESTORE PHYSIO & REHAB CENTRE (KEPALA BATAS)": "rtw_RESTORE_KEPALA BATAS",
 "OUR PHYSIO SDN BHD (BAYAN LEPAS)": "rtw_OUR_BAYAN LEPAS",
 "DIAMAGNETIC PHYSIO CENTRE SDN BHD (CHERAS)": "rtw_DIAMAGNETIC_CHERAS",
 "PHYSIOACTIVE REHAB & HEALTHCARE CENTRE (TELUK INTAN)": "rtw_PHYSIOACTIVE_TELUK INTAN",
 "PAIN PARALYSIS PHYSIOTHERAPY CENTRE (IPOH)": "rtw_PAIN_IPOH",
 "DOCUMENTATION BASED CARE (DBC IPOH)": "rtw_DOCUMENTATION_DBC IPOH",
 "COLUMBIA ASIA HOSPITAL TAIPING (TAIPING)": "rtw_COLUMBIA_TAIPING",
 "ANSON BAY MEDICAL CENTRE (TELUK INTAN)": "rtw_ANSON_TELUK INTAN",
 "REHAB CARE PHYSIOTHERAPY CENTRE (SITIAWAN)": "rtw_REHAB_SITIAWAN",
 "TAGS SPINE & JOINT SPECIALISTS (IPOH)": "rtw_TAGS_IPOH",
 "DIAMAGNETIC PHYSIO CENTRE SDN BHD (IPOH)": "rtw_DIAMAGNETIC_IPOH",
 "YAYASAN SULTAN IDRIS SHAH BAGI ORANG KURANG UPAYA PERAK (IPOH)": "rtw_YAYASAN_IPOH",
 "C KAY FITNESS RESOURCES": "rtw_C",
 "KUANTAN MEDICAL CENTRE (KUANTAN)": "rtw_KUANTAN_KUANTAN",
 "KPJ PAHANG SPECIALIST HOSPITAL SDN BHD (KUANTAN)": "rtw_KPJ_KUANTAN",
 "ACE PHYSIOTHERAPY CENTRE (CAMERON HIGHLANDS)": "rtw_ACE_CAMERON HIGHLANDS",
 "PHYSIOTHERAPY AND OCCUPATIONAL THERAPY CENTRE (POTCKB)": "rtw_PHYSIOTHERAPY_POTCKB",
 "FLEX PHYSIOTHERAPY(KT0427207-X)": "rtw_FLEX_KT0427207-X",
 "ALL REHAB SDN BHD": "rtw_ALL",
 "BIOREHAB PHYSIOTHERAPY SDN BHD (LABUAN)": "rtw_BIOREHAB_LABUAN",
 "BIOREHAB PHYSIOTHERAPY SDN BHD (KOTA KINABALU)": "rtw_BIOREHAB_KOTA KINABALU",
 "BIOREHAB PHYSIOTHERAPY SDN BHD (SANDAKAN)": "rtw_BIOREHAB_SANDAKAN",
 "BERKAT PHYSIOTHERAPY CENTRE (SANDAKAN)": "rtw_BERKAT_SANDAKAN",
 "K.K PHYSIOCARE SDN BHD (KK)": "rtw_K.K_KK",
 "MOVE WELL PHYSIOTHERAPY & REHABILITATION (KK)": "rtw_MOVE_KK",
 "VALERIE MUSCULOSKELETAL & SPORTS PHYSIOTHERAPY (KK)": "rtw_VALERIE_KK",
 "BODYCARE PHYSIO & TRADITIONAL CHINESE MEDICAL CENTRE (TCMC) (TAWAU)": "rtw_BODYCARE_TCMC",
 "TAWAU PHYSIOTHERAPY CENTRE (TAWAU)": "rtw_TAWAU_TAWAU",
 "TAGS SPINE & JOINT SPECIALISTS (KOTA KINABALU)": "rtw_TAGS_KOTA KINABALU",
 "SABAH PHYSIOTHERAPY CENTRE (KK)": "rtw_SABAH_KK",
 "DAMAI WELLNESS CENTRE, KOTA KINABALU SPECIALIST HOSPITAL SDN. BHD (KK)": "rtw_DAMAI_KK",
 "DOCUMENTATION BASED CARE ( DBC KUCHING)": "rtw_DOCUMENTATION_ DBC KUCHING",
 "REJANG HEALTHCARE CENTRE SDN BHD (SIBU)": "rtw_REJANG_SIBU",
 "TAGS SPINE & JOINT SPECIALISTS (KUCHING)": "rtw_TAGS_KUCHING",
 "TAGS SPINE & JOINT SPECIALISTS (MIRI)": "rtw_TAGS_MIRI",
 "COLUMBIA ASIA HOSPITAL BINTULU": "rtw_COLUMBIA",
 "NORMAH MEDICAL SPECIALIST CENTRE (KUCHING)": "rtw_NORMAH_KUCHING",
 "REHAB CONCEPT SDN BHD (KUCHING)": "rtw_REHAB_KUCHING",
 "COLUMBIA ASIA HOSPITAL - MIRI (TRUEPEACE": "rtw_COLUMBIA_TRUEPEAC",
 "DOCUMENTATION BASED CARE (DBC HQ)": "rtw_DOCUMENTATION_DBC HQ",
 "DOCUMENTATION BASED CARE (DBC TTDI)": "rtw_DOCUMENTATION_DBC TTDI",
 "DOCUMENTATION BASE CARE (DBC JALAN KUCHING)": "rtw_DOCUMENTATION_DBC JALAN KUCHING",
 "PUSAT FISIOTERAPI & REHABILITASI MAIWP-PICOMS (JALAN IPOH)": "rtw_PUSAT_JALAN IPOH",
 "PARKCITY MEDICAL CENTRE (DESA PARK CITY)": "rtw_PARKCITY_DESA PARK CITY",
 "TAGS SPECIALISTS CENTER SDN BHD (HQ) (JALAN PUDU ULU)": "rtw_TAGS_HQ",
 "KPJ TAWAKKAL HEALTH CENTRE (JALAN PAHANG)": "rtw_KPJ_JALAN PAHANG",
 "TAMAN DESA MEDICAL CENTRE (TAMAN DESA)": "rtw_TAMAN_TAMAN DESA",
 "NURSINAR GLOBAL ENTERPRISE (TAMAN SETIAWANGSA)": "rtw_NURSINAR_TAMAN SETIAWANGSA",
 "WQ PARK HEALTH & REHABILITATION CENTRE (SRI RAMPAI)": "rtw_WQ_SRI RAMPAI",
 "APPLE PHYSIOTHERAPY CENTRE (DESA PANDAN)": "rtw_APPLE_DESA PANDAN",
 "YOUR PHYSIO SDN BHD (HQ) (CHERAS)": "rtw_YOUR_HQ",
 "WORLD RENAISSANCE PHYSIOTHERAPY (AMPANG)": "rtw_WORLD_AMPANG",
 "BAINS MELAWATI": "rtw_BAINS",
 "HOSPITAL PUSRAWI": "rtw_HOSPITAL",
 "GLOBAL PHYSIO & REHAB CENTRE PLT": "rtw_GLOBAL",
 "MY FLEX HEALTH GROUP SDN BHD (BUKIT JALIL)": "rtw_MY_BUKIT JALIL",
 "WQ PARK HEALTH & REHABILITATION CENTRE (KELANA JAYAI)": "rtw_WQ_KELANA JAYAI",
 "SUBANG JAYA MEDICAL CENTRE (SUBANG JAYA)": "rtw_SUBANG_SUBANG JAYA",
 "ARA DAMANSARA MEDICAL CENTRE (ARA DAMANSARA)": "rtw_ARA_ARA DAMANSARA",
 "SAU SENG LUM REHABILITATION CENTRE (PUCHONG)": "rtw_SAU_PUCHONG",
 "SAU SENG LUM REHABILITATION CENTRE (PETALING JAYA)": "rtw_SAU_PETALING JAYA",
 "PUTRA MEDIC PHYSIOTHERAPY CENTRE (BANDAR PUTRA PERMAI)": "rtw_PUTRA_BANDAR PUTRA PERMAI",
 "PUTIH FISIOTERAPI CENTRE (BANGI)": "rtw_PUTIH_BANGI",
 "MOMO PHYSIOTHERAPY CENTRE (SHAH ALAM)": "rtw_MOMO_SHAH ALAM",
 "MEDWELL PHYSIOTHERAPY SDN BHD (PETALING JAYA)": "rtw_MEDWELL_PETALING JAYA",
 "MEDWELL PHYSIOTHERAPY SDN BHD (KLANG)": "rtw_MEDWELL_KLANG",
 "REGEN REHABILITATION INTERNATIONAL SDN BHD (PETALING JAYA)": "rtw_REGEN_PETALING JAYA",
 "JOINCARE REHABILITATION CENTRE (SUBANG JAYA)": "rtw_JOINCARE_SUBANG JAYA",
 "JOINCARE REHABILITATION CENTRE (KLANG)": "rtw_JOINCARE_KLANG",
 "INFINITE REHABILITATION (M) SDN BHD (SUBANG JAYA)": "rtw_INFINITE_M",
 "DAVID HEALTH SOLUTIONS (ASIA) SDN BHD (KLANG)": "rtw_DAVID_ASIA",
 "RAWANG PHYSIOTHERAPY & REHABILITATION (RAWANG)": "rtw_RAWANG_RAWANG",
 "COLUMBIA ASIA HOSPITAL – PUCHONG (PUCHONG)": "rtw_COLUMBIA_PUCHONG",
 "MYPHYSIOWORKS SDN BHD (BANTING)": "rtw_MYPHYSIOWORKS_BANTING",
 "MYPHYSIOWORKS SDN BHD (KLANG)": "rtw_MYPHYSIOWORKS_KLANG",
 "DYNAMIQUE SPORTS INJURY & REHABILITATION CENTRE (PETALING JAYA)": "rtw_DYNAMIQUE_PETALING JAYA",
 "DIAMAGNETIC PHYSIO CENTRE SDN BHD (SHAH ALAM)": "rtw_DIAMAGNETIC_SHAH ALAM",
 "DIAMAGNETIC PHYSIO CENTRE SDN BHD (SUNGAI WAY)": "rtw_DIAMAGNETIC_SUNGAI WAY",
 "DIAMAGNETIC PHYSIO CENTRE SDN BHD (RAWANG)": "rtw_DIAMAGNETIC_RAWANG",
 "SMART INTEGRATED THERAPY (SHAH ALAM)": "rtw_SMART_SHAH ALAM",
 "SUNWAY MEDICAL CENTRE SDN BHD (BANDAR SUNWAY)": "rtw_SUNWAY_BANDAR SUNWAY",
 "COLUMBIA ASIA HOSPITAL - KLANG (KLANG)": "rtw_COLUMBIA_KLANG",
 "DOCUMENTATION BASED CARE (SHAH ALAM)": "rtw_DOCUMENTATION_SHAH ALAM",
 "YOUR PHYSIO SDN BHD (PJ) (PETALING JAYA)": "rtw_YOUR_PJ",
 "WELL REHABILITATION CENTRE (SERI KEMBANGAN)": "rtw_WELL_SERI KEMBANGAN",
 "KPJ KAJANG SPECIALIST HOSPITAL (KOMPLEKS OSTIA)": "rtw_KPJ_KOMPLEKS OSTIA",
 "KPJ KAJANG SPECIALIST HOSPITAL (BERANANG)": "rtw_KPJ_BERANANG",
 "CHONG PHYSIOTHERAPY & REHABILITATION CENTRE (BALAKONG)": "rtw_CHONG_BALAKONG",
 "MY PHYSIO & REHAB CENTRE (SEPANG)": "rtw_MY_SEPANG",
 "COLUMBIA ASIA EXTENDED CARE HOSPITAL SHAH ALAM (SHAH ALAM)": "rtw_COLUMBIA_SHAH ALAM",
 "PHYSIO PLUS (PETALING JAYA)": "rtw_PHYSIO_PETALING JAYA",
 "AXIS PHYSIOTHERAPY (PETALING JAYA)": "rtw_AXIS_PETALING JAYA",
 "DAMAI PHYSIO AND REHAB (PREVIOUSLY KNOWN AS: TRICARES PHYSIO & REHAB SDN BHD) (KAJANG)": "rtw_DAMAI_PREVIOUSLY KNOWN AS: TRICARES PHYSIO & REHAB SDN BHD",
 "TAIPAN PHYSIOTHERAPY & REHABILITATION CENTRE (SUBANG JAYA)": "rtw_TAIPAN_SUBANG JAYA",
 "PHYSIOMOBILEMY SERVICES, PMMY GROUP SDN BHD (SHAH ALAM)": "rtw_PHYSIOMOBILEMY_SHAH ALAM",
 "PHYSIO ACTIVE SDN BHD": "rtw_PHYSIO",
 "SPINE SPORTS STROKE REHAB SPECIALIST SDN BHD": "rtw_SPINE",
 "PHYSIOCARE PHYSIOTHERAPY CENTRE (MINTS HEALTH AND WELLNESS ENTERPRISE": "rtw_PHYSIOCARE_MINTS HEALTH AND WELLNESS ENTERPRIS",
 "LOVE ON WHEELS HEALTHCARE SERVICES SDN BHD (PETALING JAYA)": "rtw_LOVE_PETALING JAYA",
 "PANTAI INTEGRATED REHAB SERVICES SDN BHD, HOSPITAL PANTAI IPOH (IPOH)": "rtw_PANTAI_IPOH",
 "TABUAN HEALTHCARE & NURSING (KUCHING)": "rtw_TABUAN_KUCHING",
 "MALAYSIAN MEDICAL & HEALTHCARE CENTRE (JALAN IPOH)": "rtw_MALAYSIAN_JALAN IPOH"}

# %%
def get_panel_code(i):
    if i in panel_code:
        return panel_code[i]

# %%
print(get_panel_code('COLUMBIA ASIA HOSPITAL – PUCHONG (PUCHONG)'))
# Out:
# rtw_COLUMBIA_PUCHONG

# %%
data_file1 = open('../CSV Files/Final Data/Panel Mapping/panel_with_map.csv', 'w+') 
csv_write1 = csv.writer(data_file1,sys.stdout, lineterminator='\n') 
count = 19000
d = []
for i in panel_code:
    # print(i)
    d.append(count)
    d.append("panel_code")
    d.append(panel_code[i].strip())
    d.append(i.strip())
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    count= count+1
    print("______________________________")
    print(d)
    print("______________________________")
    csv_write1.writerow(d) 
    d = []
# csv_write.close()
# Out:
# ______________________________
# [19000, 'panel_code', 'rtw_SINAR_SEGAMAT', 'SINAR REHABILITATION CENTRE (SEGAMAT)', '', '', '', '', '', '']
# ______________________________
# ______________________________
# [19001, 'panel_code', 'rtw_REHAB_KLUANG', 'REHAB HEALTHCARE SDN BHD (KLUANG)', '', '', '', '', '', '']
# ______________________________
# ______________________________
# [19002, 'panel_code', 'rtw_KLUANG_KLUANG', 'KLUANG UTAMA SPECIALIST HOSPITAL (KLUANG)', '', '', '', '', '', '']
# ______________________________
# ______________________________
# [19003, 'panel_code', 'rtw_JB_JB', 'JB PHYSIOTHERAPY SDN BHD (JB)', '', '', '', '', '', '']
# ______________________________
# ______________________________
# [19004, 'panel_code', 'rtw_GREAT_JB', 'GREAT LIFE PHYSIO & REHABILITATION (JB)', '', '', '', '', '', '']
# ______________________________
# ______________________________
# ...

# %% [markdown]
# <h1>Mapping Hierarchy :-</h1>
# <h2>Panel & Service TO Service Type TO State Mapping  </h2>

# %%
a = ["Johor","Kedah","Kelantan","Melaka","Negeri Sembilan","Pahang","Pulau Pinang","Perak","Perlis","Selangor","Terengganu","Sabah","Sarawak","Kuala Lumpur","Labuan","Putrajaya","N9","PP"]
b = ["ZON UTARA","ZON SELATAN","ZON TIMUR","ZON BORNEO","ZON TENGAH","ZON LEMBAH KLANG NEW"]

states_in_DB = {}
zones_in_DB = {}
for i in range(0,len(a)):
    states_in_DB.update({a[i].lower():int(i+1)})
for i in range(0,len(b)):
    zones_in_DB.update({b[i].lower():int(i+1)})
print(json.dumps(states_in_DB,indent=1))
print(json.dumps(zones_in_DB,indent=1))
# Out:
# {
#  "johor": 1,
#  "kedah": 2,
#  "kelantan": 3,
#  "melaka": 4,
#  "negeri sembilan": 5,
#  "pahang": 6,
#  "pulau pinang": 7,
#  "perak": 8,
#  "perlis": 9,
#  "selangor": 10,
#  "terengganu": 11,
#  "sabah": 12,
#  "sarawak": 13,
#  "kuala lumpur": 14,
#  "labuan": 15,
#  "putrajaya": 16,
#  "n9": 17,
#  "pp": 18
# }
# {
#  "zon utara": 1,
#  "zon selatan": 2,
#  "zon timur": 3,
#  "zon borneo": 4,
#  "zon tengah": 5,
#  "zon lembah klang new": 6
# }

# %%
def checkState(state_name):
    if state_name in states_in_DB:
        # print("State ={} , Value ={}".format(state_name,states_in_DB[state_name]))
        return states_in_DB[state_name]
    else:
        return -1
            
def checkZone(state_name):
    if state_name in zones_in_DB:
    #    print("Zone ={} , Value ={}".format(state_name,zones_in_DB[state_name]))
       return zones_in_DB[state_name]
    else:   
        return -2

# %%
data_file1 = open('../CSV Files/final1.csv', 'w+') 
csv_write1 = csv.writer(data_file1,sys.stdout, lineterminator='\n') 
count = 17000
d = []
for i in service_type_to_service_code_og:
    # print(i)
    d.append(count)
    d.append("rtw_sp_serviceType")
    d.append(service_type_to_service_code_og[i].strip())
    d.append(i.strip())
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    count= count+1
    # print("______________________________")
    # print(d)
    # print("______________________________")
    # csv_write1.writerow(d) 
    d = []
# csv_write.close()

# %%
# print(json.dumps(service_to_service_code_og,indent=1))
test = {"serivce":[12,23,34,45,656,67,78,89],"hhe":[112,344,56,677,78,89]}
y = (json.dumps(test,indent=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-230-8a4e1da03fb0> in <module>
#       2 test = {"serivce":[12,23,34,45,656,67,78,89],"hhe":[112,344,56,677,78,89]}
#       3 y = (json.dumps(test,indent=1))
# ----> 4 print(y["service"])
#
# TypeError: string indices must be integers

# %%
hehe = JSON.parse

# %%
data_file2 = open('../CSV Files/final2.csv', 'w+') 
csv_write2 = csv.writer(data_file2,sys.stdout, lineterminator='\n') 
count = 18000
d = []
for i in service_to_service_code_og:
    print("{} = {}".format(i,service_to_service_code_og[i].strip("\n")))
    d.append(count)
    d.append("rtw_sp_service")
    d.append(service_to_service_code_og[i].strip())
    d.append(i.strip())
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    d.append("")
    count= count+1
    # csv_write2.writerow(d) 
    d = []
# Out:
# Physiotherapy Treatment = rtw_s1_phy
# Manual Therapy = rtw_s2_man
# Pain Management = rtw_s3_pai
# Musculoskeletal Rehabilitation = rtw_s4_mus
# Sport Injuries Rehabilitation = rtw_s5_spo
# Stroke Rehabilitation = rtw_s6_str
# Spinal Cord Injury Rehabilitation = rtw_s7_spi
# Traumatic Brain Injury Rehabilitation = rtw_s8_tra
# Amputee Rehabilitation = rtw_s9_amp
# Cardiorespiratory Rehabilitation = rtw_s10_car
# Hydrotherapy = rtw_s11_hyd
# Home Therapy + Mileage = rtw_s32_hom
# Group Therapy And Exercises = rtw_s13_gro
# Burn Management = rtw_s14_bur
# Patient And Family Education Including Talk Workshop And Training = rtw_s40_pat
# Women And Men Health = rtw_s16_wom
# Other Neurological Or Rare Diseases Rehabilitation Such As Parkinson/Multiple Sclerosis/Muscular Dysthropy/Systemic Lupus/Ankylosing Spondylotis/Gullain Barre 1Syndrome = rtw_s17_oth
# Alter-G (Anti Graviti) Physio = rtw_s18_alt
# Tbion (Tibion Bionic Technology) Rehab = rtw_s19_tbi
# ...

# %%
import xlrd 
import json
import csv
import sys
# from google.colab import files
# uploaded = files.upload()

# %%
book1 = xlrd.open_workbook("../SP-New Price Reference v 0.3.xls")
worksheet1 = book1.sheet_by_index(0)
print(worksheet1)
print("Worksheet name(s): {0}".format(book1.sheet_names()))
# Out:
# Sheet  0:<Sheet1>
# Worksheet name(s): ['Sheet1']

# %%
data = open('../CSV Files/Final Data/SP Price/new_with_map.csv', 'w+')
# data = open('../CSV Files/Final Data/final_csv_with_map.csv', 'w+') 
# data = open('../CSV Files/Removal Of Null Data/CSV_Data_Without_Mapping.csv', 'w+') 
# data = open('../CSV Files/Final Data/final_csv_with_map.csv', 'w+') 
csv_writer_final = csv.writer(data,sys.stdout, lineterminator='\n')

# %%
# data = open('../CSV Files/Final Data/Panel Mapping/panel_with_map.csv', 'w+')
# csv_writer_panel = csv.writer(data,sys.stdout, lineterminator='\n')

# %%
data1 = open('../CSV Files/Final Data/SP Price/new_without_map.csv', 'w+')
# data = open('../CSV Files/Final Data/final_csv_without_map.csv', 'w+') 
# data = open('../CSV Files/Removal Of Null Data/CSV_Data_With_Mapping.csv', 'w+') 
# data = open('../CSV Files/Final Data/final_csv_without_map.csv', 'w+') 
csv_writer_final1 = csv.writer(data1,sys.stdout, lineterminator='\n')

# %%
b = []
d = []
e = []  
f = []
g = []
final = {}
count = 19000
s= ""
for i in range(1,885):
    b = worksheet1.row_values(i)
    a = b[0].strip()
    if(a==""):
        state_name = b[1].strip()
    else :
        state_name = a
        
    service_type = (b[2].strip()).replace("\n","")
    service = (b[3].strip()).replace("\n","")
    panel = (b[4].strip()).replace("\n","")
    price = b[5]
    x = checkZone(state_name.lower())
    y = checkState(state_name.lower())
    p = get_service_type_code((service_type.lower()).strip())
    q = get_service_code((service.lower()).strip())
    # State Mapping
    if(x==-2):
        e.append(y)
        e.append("")
        z = y

    # Zone Mapping
    if(y==-1):
        e.append("")
        e.append(x)
        z = x
 
    # Service Type Mapping
    if(p==None):
        print("\t{}")
    e.append(p)
    
    # Service Mapping
    e.append(q)
    # s = s + "rtw_panel_" +str(z)+"_"+(panel.split(' '))[0]
    
    # s = s + "rtw_" +str(z)+"_"+(panel.split(' '))[0] +"_"+ panel[panel.index("(")+1:panel.index(")")]
    
    # d.append(count)
    # d.append("panel_code")
    # print("\tpanel = {}".format(panel))
    # d.append(get_panel_code(panel))
    # d.append(panel)
    # d.append("")
    # d.append("")
    # d.append("")
    # d.append("")
    # d.append("")
    # d.append("")
    # count= count+1
    # csv_writer_panel.writerow(d)
    e.append(get_panel_code(panel))
    e.append(price)
    e.append("")
    e.append("")
    s = ""
    
    f.append(state_name)
    f.append(b[2])
    f.append(b[3])
    f.append(b[4])
    f.append(b[5])
    # if(i==272):

    
   
    print("__________________________________")
    print("{}".format(e))
    # print("{}\t{}\t{}\t{}\t{}".format(state_name,b[2],b[3],b[4],b[5]))
    print("__________________________________")
    csv_writer_final.writerow(e) 
    csv_writer_final1.writerow(f)
    e = []
    d = []
    f = []
# Out:
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_SINAR_SEGAMAT', 80.0, '', '']
# __________________________________
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_REHAB_KLUANG', 80.0, '', '']
# __________________________________
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_KLUANG_KLUANG', 80.0, '', '']
# __________________________________
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_JB_JB', 80.0, '', '']
# __________________________________
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_GREAT_JB', 80.0, '', '']
# __________________________________
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_BP_BATU PAHAT', 80.0, '', '']
# __________________________________
# __________________________________
# [1, '', 'rtw_st_phy', 'rtw_s1_phy', 'rtw_TAGS_JB', 70.0, '', '']
# ...

# %%
print(panel_code["COLUMBIA ASIA HOSPITAL – PUCHONG (PUCHONG)"])
# Out:
# rtw_COLUMBIA_PUCHONG

# %%
# import xlrd 
# import json
# import csv
# import sys
# # from google.colab import files
# # uploaded = files.upload()

# %%
book2 = xlrd.open_workbook("../Appendix.xls")
worksheet2 = book2.sheet_by_index(0)
print(worksheet2)
print("Worksheet name(s): {0}".format(book2.sheet_names()))
# Out:
# Sheet  0:<PERKHIDMATAN>
# Worksheet name(s): ['PERKHIDMATAN', 'MODALITIES', 'MODIFIKASI']

# %%
data = open('../CSV Files/Final Data/SP Mapping/final1.csv', 'w+') 
csv_writer_map = csv.writer(data,sys.stdout, lineterminator='\n')

# %%
data1 = open('../CSV Files/Final Data/SP Mapping/final2.csv', 'w+') 
csv_writer_no_map = csv.writer(data1,sys.stdout, lineterminator='\n')

# %%
for i in serv_type:
    print(i)
# Out:
# PHYSIOTHERAPY
# OCCUPATIONAL THERAPY
# SPEECH THERAPY
# FUNCTIONAL CAPACITY EVALUATION & REPORT
# SERVICES BY PACKAGE
# ASSESSMENT & REPORT
# DRY NEEDLING/ACUPUNCTURE
# SERVICES BY MODALITIES
# CONSULTATION
# HOSTEL
# PSYCHOLOGY
# ADMINISTRATION SERVICES

# %%
# print("Service TO Service Type TO Service Plan Mapping")
# e = []
# f = []
# for i in range(1,152):
#     b = worksheet2.row_values(i)
#     c = (b[0].strip()).replace("\n","")
    
#     if(c!=""):
#         service_type = c

#     service = (b[4].strip())

#     e.append(service_type)
#     e.append(service)
    
#     f.append(get_service_type_code(service_type.lower()))
#     f.append(get_service_code(service.lower()))
#     # print("_____________________________________")
#     # print("{} = {}".format(service_type.lower(),get_service_type_code(service_type.lower())))
#     # print("{} = {}".format(service.lower(),get_service_code(service.lower())))
#     # print("_____________________________________")   
#     if(b[2]=="PRM"):
#         e.append(3)
#         f.append(3)

#     if(b[2]=="FCE"):
#         e.append(1)
#         f.append(1)
        
#     if(b[2]=="PRM, FCE"):
#         e.append(3)
#         e.append("")
#         e.append("")
#         e.append("")

#         f.append(3)
#         f.append("")
#         f.append("")
#         f.append("")
#         print("{}".format(f))
#         csv_writer_map.writerow(e) 
#         csv_writer_no_map.writerow(f)
#         e[2]=1
#         f[2]=1

#     e.append("")#     e.append("")
#     e.append("")
#     csv_writer_map.writerow(e) 
#     f.append("")
#     f.append("")
#     f.append("")
#     csv_writer_no_map.writerow(f) 
#     print("{}".format(f))
#     f = []
#     e = []

# %%
# b = []
# e = []  
# s= ""
# for i in serv_type:
#     print(mapping_for_sp_service_details(i))
